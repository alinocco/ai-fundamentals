# %%
# %pip install numpy pandas tqdm scikit-learn matplotlib seaborn ucimlrepo torch
# Out:
# Requirement already satisfied: numpy in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (2.4.0)
# Requirement already satisfied: pandas in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: tqdm in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: scikit-learn in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: matplotlib in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (0.13.2)
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Collecting torch
#   Downloading torch-2.9.1-cp312-none-macosx_11_0_arm64.whl.metadata (30 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: certifi>=2020.12.5 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from ucimlrepo) (2025.11.12)
# Collecting filelock (from torch)
#   Downloading filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from torch) (80.9.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.5 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alinamukhomediarova/Documents/Study/ITMO/Фундаментальные основы ИИ/Labs/.venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Downloading torch-2.9.1-cp312-none-macosx_11_0_arm64.whl (74.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 7.9 MB/s  0:00:09m0:00:0100:01
# Downloading fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.0 MB/s  0:00:00 eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 8.2 MB/s  0:00:00 eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 8.6 MB/s  0:00:00
# Downloading filelock-3.20.3-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Installing collected packages: mpmath, sympy, networkx, jinja2, fsspec, filelock, torch, ucimlrepo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [ucimlrepo]/8 [torch]ck]
# Successfully installed filelock-3.20.3 fsspec-2026.1.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 sympy-1.14.0 torch-2.9.1 ucimlrepo-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
# from ucimlrepo import fetch_ucirepo 
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# steel_industry_energy_consumption = fetch_ucirepo(id=851) 

df = pd.read_csv('datasets/Steel_Industry_data.csv')
X = df.drop(columns=['Usage_kWh', 'date']).copy()
y = df['Usage_kWh']
  
day_mapping = {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}
X['Day_of_week'] = X['Day_of_week'].map(day_mapping)
X['Day_sin'] = np.sin(2 * np.pi * X['Day_of_week'] / 7)
X['Day_cos'] = np.cos(2 * np.pi * X['Day_of_week'] / 7)
X = pd.get_dummies(X, columns=['WeekStatus', 'Load_Type'])

# %%
X
# Out:
#        Lagging_Current_Reactive.Power_kVarh  \
# 0                                      2.95
# 1                                      4.46
# 2                                      3.28
# 3                                      3.56
# 4                                      4.50
# ...                                     ...
# 35035                                  4.86
# 35036                                  3.74
# 35037                                  3.17
# 35038                                  3.06
# 35039                                  3.02
#
#        Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
# 0                                      0.00        0.0
# 1                                      0.00        0.0
# 2                                      0.00        0.0
# 3                                      0.00        0.0
# 4                                      0.00        0.0
# ...                                     ...        ...
# 35035                                  0.00        0.0
# 35036                                  0.00        0.0
# 35037                                  0.07        0.0
# 35038                                  0.11        0.0
# 35039                                  0.07        0.0
#
#        Lagging_Current_Power_Factor  Leading_Current_Power_Factor    NSM  \
# 0                             73.21                        100.00    900
# 1                             66.77                        100.00   1800
# 2                             70.28                        100.00   2700
# 3                             68.09                        100.00   3600
# 4                             64.72                        100.00   4500
# ...                             ...                           ...    ...
# 35035                         62.10                        100.00  82800
# 35036                         70.71                        100.00  83700
# 35037                         76.62                         99.98  84600
# 35038                         77.72                         99.96  85500
# 35039                         77.22                         99.98      0
#
#        Day_of_week  Day_sin  Day_cos  WeekStatus_Weekday  WeekStatus_Weekend  \
# 0                0      0.0      1.0                True               False
# 1                0      0.0      1.0                True               False
# 2                0      0.0      1.0                True               False
# 3                0      0.0      1.0                True               False
# 4                0      0.0      1.0                True               False
# ...            ...      ...      ...                 ...                 ...
# 35035            0      0.0      1.0                True               False
# 35036            0      0.0      1.0                True               False
# 35037            0      0.0      1.0                True               False
# 35038            0      0.0      1.0                True               False
# 35039            0      0.0      1.0                True               False
#
#        Load_Type_Light_Load  Load_Type_Maximum_Load  Load_Type_Medium_Load
# 0                      True                   False                  False
# 1                      True                   False                  False
# 2                      True                   False                  False
# 3                      True                   False                  False
# 4                      True                   False                  False
# ...                     ...                     ...                    ...
# 35035                  True                   False                  False
# 35036                  True                   False                  False
# 35037                  True                   False                  False
# 35038                  True                   False                  False
# 35039                  True                   False                  False
#
# [35040 rows x 14 columns]

# %%
y
# Out:
# 0        3.17
# 1        4.00
# 2        3.24
# 3        3.31
# 4        3.82
#          ...
# 35035    3.85
# 35036    3.74
# 35037    3.78
# 35038    3.78
# 35039    3.67
# Name: Usage_kWh, Length: 35040, dtype: float64

# %%
X_all = X.to_numpy(dtype=np.float32)
y_all = y.to_numpy(dtype=np.float32)

# %%
(X_all.shape, y_all.shape)
# Out:
# ((35040, 14), (35040,))

# %%
from sklearn.preprocessing import StandardScaler

split_idx = int(0.8 * len(X_all))

X_train = X_all[:split_idx]
X_test = X_all[split_idx:]
y_train = y_all[:split_idx]
y_test = y_all[split_idx:]

scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train = scaler_X.fit_transform(X_train)
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()

X_test = scaler_X.transform(X_test)
y_test = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# %%
import torch
import torch.nn as nn
from tqdm import tqdm

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.w1 = nn.Linear(hidden_size, hidden_size)
        self.w2 = nn.Linear(input_size, hidden_size)
        self.w3 = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hx = None):
        x = torch.tensor(x)
        seq_size, _ = x.shape
        if hx is None:
            hx = torch.zeros((self.hidden_size))
        h_t = hx.clone()
        outputs = []
        for i in range(seq_size):
            h_t = torch.tanh(self.w1(h_t) + self.w2(x[i,:]))
            outputs.append(self.w3(h_t))
        outputs = torch.stack(outputs)
        return outputs, h_t

# %%
criterion = nn.MSELoss()
rnn = RNN(X_train.shape[1], 128, 1)
optimizer = torch.optim.SGD(rnn.parameters(), lr=0.01)
batch_size = 32

# %%
import matplotlib.pyplot as plt

train_losses = []
test_losses = []

for epoch in tqdm(range(10)):
    total_loss = 0
    count = 0
    for batch_idx in range(len(X_train) // batch_size):
        batch = X_train[batch_idx * batch_size : (batch_idx + 1) * batch_size]
        targets = torch.tensor(y_train[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(batch_size, 1))
        outputs, hidden = rnn(batch)
        loss = criterion(outputs, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        count += len(batch)
    train_losses.append(total_loss / count)

    test_loss = 0
    test_count = 0
    for batch_idx in range(len(X_test) // batch_size):
        batch = X_test[batch_idx * batch_size : (batch_idx + 1) * batch_size]
        targets = torch.tensor(y_test[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(1, batch_size, 1))
        outputs, hidden = rnn.forward(batch)
        test_loss += torch.sum((outputs - targets) ** 2).item()
        test_count += len(batch)
    test_losses.append(test_loss / test_count)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss', marker='s')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 100%|██████████| 10/10 [00:37<00:00,  3.79s/it]

# %%
from source.rnn import RNN as RNN_numpy
import numpy as np
import matplotlib.pyplot as plt

rnn = RNN_numpy(input_size=X_train.shape[1], hidden_size=128, output_size=1, lr=0.001)

train_losses = []
test_losses = []

for epoch in tqdm(range(10)):
    epoch_loss = 0
    count = 0
    
    for i in range(0, len(X_train), batch_size):
        batch_x = X_train[i : i + batch_size]
        batch_y = y_train[i : i + batch_size].reshape(-1, 1)
        loss = rnn.backward(batch_x, batch_y)
        epoch_loss += loss
        count += len(batch_x)
    
    train_losses.append(epoch_loss / count)

    test_loss = 0
    test_count = 0
    for batch_idx in range(len(X_test) // batch_size):
        batch = X_test[batch_idx * batch_size : (batch_idx + 1) * batch_size]
        targets = np.array(y_test[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(1, batch_size, 1))
        outputs, hidden = rnn.forward(batch)
        test_loss += np.sum((outputs - targets) ** 2)
        test_count += len(batch)
    
    test_losses.append(test_loss / test_count)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss', marker='s')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]

# %%
mse_loss = 0
for batch_idx in range(len(X_test) // batch_size):
    batch = X_test[batch_idx * batch_size : (batch_idx + 1) * batch_size]
    targets = np.array(y_test[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(1, batch_size, 1))
    outputs, hidden = rnn.forward(batch)
    mse_loss += np.sum((outputs - targets) ** 2)

print("Total MSE Loss on test set:", mse_loss)
# Out:
# Total MSE Loss on test set: 3116.570003306504

# %%
from source.lstm import LSTM as LSTM_numpy
import numpy as np
import matplotlib.pyplot as plt

lstm = LSTM_numpy(input_size=X_train.shape[1], hidden_size=128, output_size=1, lr=0.001)

train_losses = []
test_losses = []

for epoch in tqdm(range(10)):
    epoch_loss = 0
    count = 0
    
    for i in range(0, len(X_train), batch_size):
        batch_x = X_train[i : i + batch_size]
        batch_y = y_train[i : i + batch_size].reshape(-1, 1)
        loss = lstm.backward(batch_x, batch_y)
        epoch_loss += loss
        count += len(batch_x)
    
    train_losses.append(epoch_loss / count)

    test_loss = 0
    test_count = 0
    for batch_idx in range(len(X_test) // batch_size):
        batch = X_test[batch_idx * batch_size : (batch_idx + 1) * batch_size]
        targets = np.array(y_test[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(1, batch_size, 1))
        outputs, hidden = lstm.forward(batch)
        test_loss += np.sum((outputs - targets) ** 2)
        test_count += len(batch)
    
    test_losses.append(test_loss / test_count)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss', marker='s')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 100%|██████████| 10/10 [00:54<00:00,  5.49s/it]

# %%
mse_loss = 0
for batch_idx in range(len(X_test) // batch_size):
    batch = X_test[batch_idx * batch_size : (batch_idx + 1) * batch_size]
    targets = np.array(y_test[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(1, batch_size, 1))
    outputs, hidden = lstm.forward(batch)
    mse_loss += np.sum((outputs - targets) ** 2)

print("Total MSE Loss on test set:", mse_loss)
# Out:
# Total MSE Loss on test set: 53.499710366010405

# %%
from source.gru import GRU as GRU_numpy
import numpy as np
import matplotlib.pyplot as plt

gru = GRU_numpy(input_size=X_train.shape[1], hidden_size=128, output_size=1, lr=0.001)

train_losses = []
test_losses = []

for epoch in tqdm(range(10)):
    epoch_loss = 0
    count = 0
    
    for i in range(0, len(X_train), batch_size):
        batch_x = X_train[i : i + batch_size]
        batch_y = y_train[i : i + batch_size].reshape(-1, 1)
        loss = gru.backward(batch_x, batch_y)
        epoch_loss += loss
        count += len(batch_x)
    
    train_losses.append(epoch_loss / count)

    test_loss = 0
    test_count = 0
    for batch_idx in range(len(X_test) // batch_size):
        batch = X_test[batch_idx * batch_size : (batch_idx + 1) * batch_size]
        targets = np.array(y_test[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(1, batch_size, 1))
        outputs, hidden = gru.forward(batch)
        test_loss += np.sum((outputs - targets) ** 2)
        test_count += len(batch)
    
    test_losses.append(test_loss / test_count)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss', marker='s')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 100%|██████████| 10/10 [00:53<00:00,  5.32s/it]

# %%
mse_loss = 0
for batch_idx in range(len(X_test) // batch_size):
    batch = X_test[batch_idx * batch_size : (batch_idx + 1) * batch_size]
    targets = np.array(y_test[batch_idx * batch_size : (batch_idx + 1) * batch_size].reshape(1, batch_size, 1))
    outputs, hidden = gru.forward(batch)
    mse_loss += np.sum((outputs - targets) ** 2)

print("Total MSE Loss on test set:", mse_loss)
# Out:
# Total MSE Loss on test set: 76.17183941588266
